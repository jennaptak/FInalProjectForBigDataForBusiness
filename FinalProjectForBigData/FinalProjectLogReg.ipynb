# %% [markdown]
# Create a spark session and load the Housing Data set

# %%
from pyspark.sql import SparkSession

# %%
# File location and type
file_location = "/FileStore/tables/red_or_white_wine-6.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","
 
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# %% [markdown]
# Data pre-processing

# %%
# Import the required libraries
 
from pyspark.sql.functions import datediff,date_format,to_date,to_timestamp

# %%
import pyspark.sql.functions as f

# %%
df=df.withColumn('type',df.type.cast('integer'))

# %%
data = df.select(['fixed acidity',
'volatile acidity',
'citric acid',
'residual sugar',
'chlorides',
'free sulfur dioxide',
'total sulfur dioxide',
'density',
'pH',
'sulphates',
'alcohol',
'quality',
'type'
])

# %%
df.printSchema()
# Out:
# root
#  |-- fixed acidity: double (nullable = true)
#  |-- volatile acidity: double (nullable = true)
#  |-- citric acid: double (nullable = true)
#  |-- residual sugar: double (nullable = true)
#  |-- chlorides: double (nullable = true)
#  |-- free sulfur dioxide: double (nullable = true)
#  |-- total sulfur dioxide: double (nullable = true)
#  |-- density: double (nullable = true)
#  |-- pH: double (nullable = true)
#  |-- sulphates: double (nullable = true)
#  |-- alcohol: double (nullable = true)
#  |-- quality: integer (nullable = true)
#  |-- type: integer (nullable = true)

# %%
df=df.dropna()

# %%
print((df.count(),len(df.columns)))
# Out:
# (0, 13)

# %%
# Create a 70-30 train test split
 
train_data,test_data=data.randomSplit([0.7,0.3])

# %%
print((train_data.count(),len(train_data.columns)))
# Out:
# (4526, 13)

# %%
print((test_data.count(),len(test_data.columns)))
# Out:
# (1971, 13)

# %%
# Import the required libraries
 
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.feature import VectorAssembler,StringIndexer ,OneHotEncoder
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator

# %% [markdown]
# Building the Logistic Regression model

# %%
type_indexer = StringIndexer(inputCol='type',outputCol='type_index',handleInvalid='keep')

# %%
data_encoder = OneHotEncoder(inputCols=['type_index'], outputCols= ['type_vec'],
                                      handleInvalid='keep')

# %%
assembler= VectorAssembler(
                inputCols=['fixed acidity',
'volatile acidity',
'citric acid',
'residual sugar',
'chlorides',
'free sulfur dioxide',
'total sulfur dioxide',
'density',
'pH',
'sulphates',
'alcohol',
'type_vec'
],
outputCol="features")

# %%
lr_model = LogisticRegression(labelCol='quality')

# %%
pipe = Pipeline(stages=[type_indexer,data_encoder,assembler,lr_model])

# %%
fit_model=pipe.fit(train_data)

# %%
# Store the results in a dataframe
 
results = fit_model.transform(test_data)

# %%
results.select(['quality','prediction']).show()
# Out:
# +-------+----------+
# |quality|prediction|
# +-------+----------+
# |      6|       7.0|
# |      6|       6.0|
# |      5|       5.0|
# |      4|       6.0|
# |      6|       7.0|
# |      5|       6.0|
# |      7|       6.0|
# |      6|       6.0|
# |      5|       6.0|
# |      6|       6.0|
# |      5|       6.0|
# |      6|       7.0|
# |      8|       6.0|
# |      6|       6.0|
# |      6|       6.0|
# |      6|       6.0|
# |      6|       7.0|
# |      6|       6.0|
# |      6|       7.0|
# |      7|       7.0|
# +-------+----------+
# only showing top 20 rows

# %% [markdown]
# Evaluating the model

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
ACC_evaluator = MulticlassClassificationEvaluator(
    labelCol="quality", predictionCol="prediction", metricName="accuracy")

# %%
accuracy = ACC_evaluator.evaluate(results)

# %%
print("The accuracy of the decision tree classifier is {}".format(accuracy))
# Out:
# The accuracy of the decision tree classifier is 0.5352612886859462
